# %% [markdown]
# # 作業一
#
# ## 1. 你選的這組資料為何重要
#
# 預測與分析心血管疾病 --> 對世界很有貢獻
#
#
# ## 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
# 提供者 : 一些醫院與心血管疾病的機構
# 以什麼方式蒐集 : 對志願的患者者進行測試並得到特定特徵的數據 ( 年齡、血壓、心搏、膽固醇 ... )
#
#
# ## 3. 蒐集而來的資料型態為何
#
# 結構化的表格與量化的數值
#
#
# ## 4. 這組資料想解決的問題如何評估
#
# 分類問題
# 可以看各個特徵中分布情況去找出對病情影響最大的特徵
#
#
# ***

# %% [markdown]
# # 作業二
#
# ## 1. 核心問題為何
#
# 一個城市中，找出載客人數的巔峰時段，與客人密集度的分布
# 因此，得知各個時段的客人數量與分布情況後
# 就可以適當的安排司機，以避免掉空在城市裡繞來繞去耗油又沒客人的情況
#
# ## 2. 資料從何而來
#
# 維持現有模式，紀錄目前每個司機每天的路線與載客情況，統計1個月
# 並針對這一個月的資料做一次分析，再重新分配司機的行程
# 同樣地需要繼續統計，並修改
#
# ## 3. 蒐集而來的資料型態為何
#
# 路線 : 包含了時間 ( 數值 ) 與 路線 ( 可以是"圖像"或是"文字與數值" )
# 載客情況 : 時間點 ( 數值 ) 與 乘客上下的起始點 ( 也是路線 )
#
# ## 4. 你要回答的問題，其如何評估
#
# 比較空車率是否有下降
#
# ***

# %% [markdown]
# # 作業三
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(Y, Y_hat):
    
    MSE = sum((Y - Y_hat) ** 2) / len (Y)
    
    return MSE

# %%
def mean_absolute_error(Y, Y_hat):
    
    MAE = sum(abs(Y - Y_hat)) / len (Y)
    
    return MAE

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 289.218
# The Mean absolute error is 13.727
